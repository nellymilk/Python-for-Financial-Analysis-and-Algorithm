# %% [markdown]
# ## pandas--data input and output

# %%
pwd
# Out:
# '/Users/nelly/Desktop/Python-for-Financial-Analysis-and-Algorithm/05-Pandas-with-Time-Series'

# %%
import pandas as pd

# %%
data = pd.read_csv('./time_data/walmart_stock.csv')

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
data.to_csv('my_output',index=False)

# %%
ls
# Out:
# Datetime Index.ipynb*        Untitled1.ipynb
# Rolling and Expanding.ipynb* my_output
# Time Resampling.ipynb*       pandas--groupby.ipynb
# Time Shifting.ipynb*         pandas--missingData.ipynb
# Untitled.ipynb               time_data/

# %%
pd.read_csv('my_output').head()
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800  52.619235
# 1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300  52.078475
# 2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200  51.825539
# 3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400  51.459220
# 4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300  51.616215

# %%
pd.read_excel('xxxxx',sheetname='vvv')

# %%
pd.read_html('https://.....')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
data.to_sql('my_table',engine)

# %%
sqldf = pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#       index        Date       Open       High        Low      Close    Volume  \
# 0         0  2012-01-03  59.970001  61.060001  59.869999  60.330002  12668800
# 1         1  2012-01-04  60.209999  60.349998  59.470001  59.709999   9593300
# 2         2  2012-01-05  59.349998  59.619999  58.369999  59.419998  12768200
# 3         3  2012-01-06  59.419998  59.450001  58.869999  59.000000   8069400
# 4         4  2012-01-09  59.029999  59.549999  58.919998  59.180000   6679300
# 5         5  2012-01-10  59.430000  59.709999  58.980000  59.040001   6907300
# 6         6  2012-01-11  59.060001  59.529999  59.040001  59.400002   6365600
# 7         7  2012-01-12  59.790001  60.000000  59.400002  59.500000   7236400
# 8         8  2012-01-13  59.180000  59.610001  59.009998  59.540001   7729300
# 9         9  2012-01-17  59.869999  60.110001  59.520000  59.849998   8500000
# 10       10  2012-01-18  59.790001  60.029999  59.650002  60.009998   5911400
# ...
